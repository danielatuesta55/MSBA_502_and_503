# %% [markdown]
# # CryptoCurrency Exchange Program
#
# ### Webscrapping, API, Pandas & Python
#
# This workbook has the code that will generate a GUI for the user to ask for the four most important coins in market and see the actual conversion rate on them. Furthermore the user will be able to add how much they want to buy and what would the total cost be if they decided to buy. The program will generate a csv file containing all the information needed.
#
# ![crypto](https://media.giphy.com/media/MFabj1E9mgUsqwVWHu/giphy-downsized-large.gif)

# %% [markdown]
# ## Final Code
# It is working

# %%
#This code was created by Jorge Daniel Atuesta Nov 13 2022
"""Before you start read this: Make sure to pick which API you want to hit on line 17 or 18. 
I did it this way since I am uploading to github and I don't want other people to hit my API.
If you are testing use my repo on github if you are evaluating than please comment line 18 and uncomment line 17"""

# Import dependencies 
import pandas as pd 
import numpy as np
import tkinter 
import tkinter.messagebox
import tkinter.ttk
import requests
import json
import sys

#Step 1: Try and except block to hit the API
try:
    #response = requests.get('http://api.coinlayer.com/api/live?access_key=5c5f1acb20cc2f5f539ac097f3234258&symbols=BTC,ETH,BNB,XRP')
    response = requests.get("https://raw.githubusercontent.com/danielatuesta55/MSBA_502_and_503/main/Homeworks/HW_5/json/json_static.txt")
    data = json.loads(response.text)
    #print(json.dumps(data, indent = 4))
    rates= data["rates"]
    #print(rates)
except Exception as err:
    print(f"Unexpected {err=}, {type(err)=}")
    raise Exception("Double check the website/API link")
    sys.exit(1)

# Step 2: Create the functions 
# Two functions for two buttons. 1 convert currency 2. Close Converter

#Function 1
def convertCurrency():
    """Using this function to convert user input into $ for crypto"""
    #Make variables global
    global btc_box,bnb_box,eth_box,xrp_box        
    #Get quant values from user input and check if they are float if not than error message box
    try:
        value1 = float(btc_box.get()) 
        value2 = float(bnb_box.get())
        value3 = float(eth_box.get())
        value4 = float(xrp_box.get())
        #Create list quant to hold the user quant values 
        quant = [value2,value1,value3,value4]
        #Showinfo message using tkinter to tell user the conversions file was a success
        tkinter.messagebox.showinfo("Complete", "The conversions where stored in crypto_conversion.csv")
    #If values in boxes can not be converted to a float than display error 
    except ValueError:
        tkinter.messagebox.showerror("Error","Sorry, the report could not be written. Check that only numeric values are entered.")
       

    # Get values in list format to create df from dic
    price = rates.values()
    #convert to list
    price = list(price)
    currency = rates.keys()
    #multiply and convert results to list
    cost = list(np.multiply(price,quant))
    exchange = list(np.divide(1,price))
    #Create dic content to create df
    details = {'Currency':currency,
               'Price': price,
               'Quantity':quant,
               'Cost (USD)': cost,
               'Exchange Rate USD:COIN':exchange
              }  
    # creating a Dataframe object 
    df = pd.DataFrame(details)
    #Sum all values in the cost USD column to prompt the user what is the total of their transaction
    total_cost = df['Cost (USD)'].sum()
    #Create the two new rows to append to existing df
    new_row = {'Currency':'--','Price':'--','Quantity':'--','Cost (USD)':'--','Exchange Rate USD:COIN':'--'}
    new_row2 = {'Currency':'Total','Price':'--','Quantity':'--','Cost (USD)':total_cost,'Exchange Rate USD:COIN':'--'}
    #Append rows to df
    df2 = df.append(new_row, ignore_index=True)
    df3 = df2.append(new_row2, ignore_index=True)
    #Save last version of df into a CSV in the same folder of the workbook
    df3.to_csv('crypto_conversion.csv',index=False)


#Second Function

def closeConverter():
    """Created this function to use for the button to close the GUI"""
    root.destroy()


#Create root
root = tkinter.Tk()
root.title("Exchange rate calculator")
root.configure(bg = "light salmon")
#root.geometry("400x100")

#Create labels
btc_box = tkinter.Label(root, text = "BTC:")
btc_box.configure(bg = "light salmon")
btc_box.grid(row = 0, column = 0)

bnb_box = tkinter.Label(root, text = "BNB:")
bnb_box.configure(bg = "light salmon")
bnb_box.grid(row = 1, column = 0)

eth_box = tkinter.Label(root, text = "ETH:")
eth_box.configure(bg = "light salmon")
eth_box.grid(row = 0, column = 2)

xrp_box = tkinter.Label(root, text = "XRP:")
xrp_box.configure(bg = "light salmon")
xrp_box.grid(row = 1, column = 2)


#Placing boxes in the grid
btc_box = tkinter.Entry(root, width = 15)
btc_box.insert(0, 1)
btc_box.grid(row = 0, column = 1)

bnb_box = tkinter.Entry(root, width = 15)
bnb_box.insert(0, 1)
bnb_box.grid(row = 1, column = 1)

eth_box = tkinter.Entry(root, width = 15)
eth_box.insert(0, 1)
eth_box.grid(row = 0, column = 3)

xrp_box = tkinter.Entry(root, width = 15)
xrp_box.insert(0, 1)
xrp_box.grid(row = 1, column = 3)

#Create the buttons

convert_currency_button = tkinter.Button(root, text = "Convert Currency", command = convertCurrency)
convert_currency_button.configure(bg= 'pale green')
convert_currency_button.grid(row = 0, column = 4,sticky = "w", padx = 5, pady = 5)

convert_currency_button = tkinter.Button(root, text = "Close Converter", command = closeConverter)
convert_currency_button.configure(bg= 'dark orange')
convert_currency_button.grid(row = 1, column = 4,sticky = "w", padx = 5, pady = 5)

#init root with command 
root.mainloop()

# %% [markdown]
# ## This code served as an initial version to solve the task
#
# DO NOT USE ONLY USE CODE ABOVE

# %%
# Import dependencies 
import pandas as pd 
import numpy as np
import tkinter 
import tkinter.messagebox
import tkinter.ttk
import requests
import json

# Two functions for two buttons. 1 convert currency 2. Close Converter

def convertCurrency():
    """Using this function to convert user input into $ for crypto"""
    global btc_box,bnb_box,eth_box,xrp_box
    #Get quant values from user input 
    try:
        value1 = float(btc_box.get()) 
        value2 = float(bnb_box.get())
        value3 = float(eth_box.get())
        value4 = float(xrp_box.get())
    
        quant = [value2,value1,value3,value4]
        tkinter.messagebox.showinfo("Complete", "The conversions where stored in crypto_conversion.csv")
    #If values in boxes are not numberic than display error 
    except ValueError:
        tkinter.messagebox.showerror("Error","Sorry, the report could not be written. Check that only numeric values are entered.")
       

    #response = requests.get('http://api.coinlayer.com/api/live?access_key=5c5f1acb20cc2f5f539ac097f3234258&symbols=BTC,ETH,BNB,XRP')
    try:
        response = requests.get("https://raw.githubusercontent.com/danielatuesta55/MSBA_502_and_503/main/Homeworks/HW_5/json/json_static.txt")
        data = json.loads(response.text)
        #print(json.dumps(data, indent = 4))
        rates= data["rates"]
        #print(rates)
    except Exception as err:
        print(f"Unexpected {err=}, {type(err)=}")
        raise
    # dictionary with list object in values
    # Get values in list format to create df from dic

    price = rates.values()
    price = list(price)
    currency = rates.keys()
    #quant =[1,1,2,2] #User get form GUI amount
    cost = list(np.multiply(price,quant))
    exchange = list(np.divide(1,price))

    details = {'Currency':currency,
               'Price': price,
               'Quantity':quant,
               'Cost USD': cost,
               'Exchange Rate USD:COIN':exchange
              }  
    # creating a Dataframe object 
    df = pd.DataFrame(details)
    df.to_csv('crypto_conversion.csv',index=False)


    
    
def closeConverter():
    """Created this function to use for the button to close the GUI"""
    root.destroy()

    
#Create root
root = tkinter.Tk()
root.title("Exchange rate calculator")
root.configure(bg = "light salmon")

#Create labels
btc_box = tkinter.Label(root, text = "BTC:")
btc_box.configure(bg = "light salmon")
btc_box.grid(row = 0, column = 0)

bnb_box = tkinter.Label(root, text = "BNB:")
bnb_box.configure(bg = "light salmon")
bnb_box.grid(row = 1, column = 0)

eth_box = tkinter.Label(root, text = "ETH:")
eth_box.configure(bg = "light salmon")
eth_box.grid(row = 0, column = 2)

xrp_box = tkinter.Label(root, text = "XRP:")
xrp_box.configure(bg = "light salmon")
xrp_box.grid(row = 1, column = 2)


#Placing boxes in the grid
btc_box = tkinter.Entry(root, width = 5)
btc_box.grid(row = 0, column = 1)

bnb_box = tkinter.Entry(root, width = 5)
bnb_box.grid(row = 1, column = 1)

eth_box = tkinter.Entry(root, width = 5)
eth_box.grid(row = 0, column = 3)

xrp_box = tkinter.Entry(root, width = 5)
xrp_box.grid(row = 1, column = 3)

#Create the buttons

convert_currency_button = tkinter.Button(root, text = "Convert Currency", command = convertCurrency)
convert_currency_button.configure(bg= 'pale green')
convert_currency_button.grid(row = 0, column = 4)

convert_currency_button = tkinter.Button(root, text = "Close Converter", command = closeConverter)
convert_currency_button.configure(bg= 'dark orange')
convert_currency_button.grid(row = 1, column = 4)

root.mainloop()
# Out:
# Unexpected err=JSONDecodeError('Expecting value: line 2 column 1 (char 1)'), type(err)=<class 'json.decoder.JSONDecodeError'>
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\danie\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "<ipython-input-56-cda4c1cb70c7>", line 32, in convertCurrency
#     data = json.loads(response.text)
#   File "C:\Users\danie\anaconda3\lib\json\__init__.py", line 357, in loads
#     return _default_decoder.decode(s)
#   File "C:\Users\danie\anaconda3\lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "C:\Users\danie\anaconda3\lib\json\decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 2 column 1 (char 1)

# %% [markdown]
# # This is working to get data from API
#
# Once API is hit it stores the values in Dictionary format in the variable name price

# %% [markdown]
# # Building the csv using Pandas!
#
# Missing getting the quant variable from user response

# %%
# dictionary with list object in values
# Get values in list format to create df from dic

price = rates.values()
price = list(x)
currency = rates.keys()
quant =[1,1,2,2] #User get form GUI amount
cost = list(np.multiply(price,quant))
exchange = list(np.divide(1,price))

details = {'Currency':currency,
           'Price': price,
           'Quantity':quant,
           'Cost USD': cost,
           'Exchange Rate USD:COIN':exchange       
          }  
# creating a Dataframe object 
df = pd.DataFrame(details)
df
# Out:
#   Currency         Price  Quantity      Cost USD  Exchange Rate USD:COIN
# 0      BNB    278.231325         1    278.231325                0.003594
# 1      BTC  16677.907140         1  16677.907140                0.000060
# 2      ETH   1244.796556         2   2489.593112                0.000803
# 3      XRP      0.346730         2      0.693460                2.884088

# %%
print(x)
print(y)
# Out:
# dict_values([278.231325, 16677.90714, 1244.796556, 0.34673])
# dict_keys(['BNB', 'BTC', 'ETH', 'XRP'])

# %% [markdown]
# # Build GUI
#
# From this I need to put the pices together

# %%
# Two functions for two buttons. 1 convert currency 2. Close Converter

def convertCurrency():
    """Using this function to convert user input into $ for crypto"""
    global btc_box,bnb_box,eth_box,xrp_box
    #Get quant values from user input 
    value1 = float(btc_box.get()) # Is this where I store quant??? I can do append to list quant or quant += float (btc...)
    value2 = float(bnb_box.get())
    value3 = float(eth_box.get())
    value4 = float(xrp_box.get())
    quant = [value1,value2,value3,value4]

def closeConverter():
    """Created this function to use for the button to close the GUI"""
    root.destroy()

#Create root
root = tkinter.Tk()
root.title("Exchange rate calculator")
root.configure(bg = "light salmon")

#Create labels
btc_box = tkinter.Label(root, text = "BTC:")
btc_box.configure(bg = "light salmon")
btc_box.grid(row = 0, column = 0)

bnb_box = tkinter.Label(root, text = "BNB:")
bnb_box.configure(bg = "light salmon")
bnb_box.grid(row = 1, column = 0)

eth_box = tkinter.Label(root, text = "ETH:")
eth_box.configure(bg = "light salmon")
eth_box.grid(row = 0, column = 2)

xrp_box = tkinter.Label(root, text = "XRP:")
xrp_box.configure(bg = "light salmon")
xrp_box.grid(row = 1, column = 2)


#Placing boxes in the grid
btc_box = tkinter.Entry(root, width = 5)
btc_box.grid(row = 0, column = 1)

bnb_box = tkinter.Entry(root, width = 5)
bnb_box.grid(row = 1, column = 1)

eth_box = tkinter.Entry(root, width = 5)
eth_box.grid(row = 0, column = 3)

xrp_box = tkinter.Entry(root, width = 5)
xrp_box.grid(row = 1, column = 3)

#Create the buttons

convert_currency_button = tkinter.Button(root, text = "Convert Currency", command = convertCurrency)
convert_currency_button.configure(bg= 'pale green')
convert_currency_button.grid(row = 0, column = 4)

convert_currency_button = tkinter.Button(root, text = "Close Converter", command = closeConverter)
convert_currency_button.configure(bg= 'dark orange')
convert_currency_button.grid(row = 1, column = 4)

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-393105c8dd8d> in <module>
#      16
#      17 #Create root
# ---> 18 root = tkinter.Tk()
#      19 root.title("Exchange rate calculator")
#      20 root.configure(bg = "light salmon")
#
# NameError: name 'tkinter' is not defined

# %%
# WHEN I NEED TO CLOSE A TOP LEVEL (SECOND WINDOW) USING A BUTTON
#https://www.tutorialspoint.com/how-to-close-only-the-toplevel-window-in-python-tkinter
#     new_window = tkinter.Toplevel()
#     new_window.title("Complete")
#     new_label = tkinter.Label(new_window, text = "The conversions where stored in crypto_conversion.csv")
#     new_label.grid(row=0,column=0)
#     button = tkinter.Button(new_window, text="Ok", command=new_window.destroy)
#     button.grid(row=1,column=1)

# %%
#If values in boxes are not numberic than display error wit tkinter.errormessage
va1 = ['231',12]
va2 = 2 
va3 = 3

if isinstance(quant ,(int, float)):
    print('Number is either int or float')
else:
    print("Error")
# Out:
# Number is not an int or float
